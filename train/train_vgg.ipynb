# %%
import os
os.listdir("/kaggle/input/image-colorization-dataset")
# Out:
# ['data']

# %%
from glob import glob

train_color = glob(
    "/kaggle/input/image-colorization-dataset/data/train_color/**/*.[jp][pn]g",
    recursive=True
)

train_black = glob(
    "/kaggle/input/image-colorization-dataset/data/train_black/**/*.[jp][pn]g",
    recursive=True
)

test_color = glob(
    "/kaggle/input/image-colorization-dataset/data/test_color/**/*.[jp][pn]g",
    recursive=True
)

test_black = glob(
    "/kaggle/input/image-colorization-dataset/data/test_black/**/*.[jp][pn]g",
    recursive=True
)

# %% [markdown]
# input train black, target train color

# %%
from sklearn.model_selection import train_test_split

val_color, test_color, val_black, test_black = train_test_split(
    test_color,
    test_black,
    test_size=0.5,     #50% test 50% val
    random_state=42,
    shuffle=True
)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import rgb2lab, lab2rgb
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim
import time

# %%
BATCH_SIZE = 32
IMAGE_SIZE = 256
LR = 2e-5
EPOCHS = 50
PATIENCE = 15
MIN_DELTA = 1e-4

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class LabDataset(Dataset):
    def __init__(self, black_images, color_images, transform=None):
        self.black_images = black_images
        self.color_images = color_images
        self.transform = transform

    def __len__(self):
        return len(self.black_images)

    def __getitem__(self, idx):
        black = Image.open(self.black_images[idx]).convert("L")
        color = Image.open(self.color_images[idx]).convert("RGB")

        if self.transform:
            black = self.transform(black)
            color = self.transform(color)

        #RGBto LAB
        color = np.array(color)
        lab = rgb2lab(color).astype("float32")

        L  = lab[:, :, 0] / 50.0 - 1.0        # [-1,1]
        ab = lab[:, :, 1:] / 110.0            # [-1,1]

        L  = torch.from_numpy(L).unsqueeze(0)
        ab = torch.from_numpy(ab).permute(2,0,1)

        return L, ab

# %%
transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)),
    transforms.RandomHorizontalFlip(),
])

# %%
train_dataset = LabDataset(
    black_images=train_black,
    color_images=train_color,
    transform=transform
)

train_loader = DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=0,
    pin_memory=True
)

# %%
test_dataset = LabDataset(
    black_images=test_black,
    color_images=test_color,
    transform=transform
)

test_loader = DataLoader(
    test_dataset,
    batch_size=1,
    shuffle=False
)

# %%
val_dataset = LabDataset(
    black_images=val_black,
    color_images=val_color,
    transform=transform
)

val_loader = DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=0,
    pin_memory=True
)

# %%
print('Training Set: ', len(train_dataset))
print('Validation Set: ', len(val_dataset))
print('Test Set: ', len(test_dataset))
# Out:
# Training Set:  5000
# Validation Set:  369
# Test Set:  370

# %% [markdown]
# psnr (peak signal to noise ratio) -> ngukur sbrp mirip hasil gambar model dgn gmbr asli scr angka piksel (salah dikit -> psnr tinggi, salah banyak -> psnr rendah
#
# ssim (structural similarity index) -> sbrp mirip struktural visual gmbr hasil model dengan gambar asli mnurut pov human

# %%
def lab_to_rgb(L, ab):
    if L.max() <= 1.0:
        L = L * 100.0

    if np.abs(ab).max() <= 1.0:
        ab = ab * 128.0

    lab = np.zeros((L.shape[0], L.shape[1], 3))
    lab[:, :, 0] = L
    lab[:, :, 1:] = ab

    # lab to rgb
    rgb = lab2rgb(lab)

    return np.clip(rgb, 0, 1)

# %%
def compute_metrics(model, dataset, n_samples=50):
    model.eval()
    psnr_list, ssim_list = [], []

    for i in range(n_samples):
        with torch.no_grad():
            L, ab = dataset[i]

            if L.dim() == 3:        # [1,H,W]
                L = L.unsqueeze(0)  # [B,1,H,W]

            L = L.to(device)
            pred_ab = model(L)      # [B,2,H,W]

        L_img = L[0,0].cpu().numpy()   # [H,W]

        if ab.dim() == 4:              # [B,2,H,W]
            ab_gt = ab[0].permute(1,2,0).cpu().numpy()
        elif ab.dim() == 3:            # [2,H,W]
            ab_gt = ab.permute(1,2,0).cpu().numpy()
        else:                          # [H,W,2]
            ab_gt = ab.cpu().numpy()
            
        ab_pred = pred_ab[0].permute(1,2,0).cpu().numpy()

        gt_rgb   = lab_to_rgb(L_img, ab_gt)
        pred_rgb = lab_to_rgb(L_img, ab_pred)

        psnr_val = psnr(gt_rgb, pred_rgb, data_range=1.0)
        ssim_val = ssim(gt_rgb, pred_rgb, channel_axis=2, data_range=1.0)

        psnr_list.append(psnr_val)
        ssim_list.append(ssim_val)

    return psnr_list, ssim_list

# %%
def plot_results(model, dataset, start_idx=1, num_samples=5):
    model.eval()
    plt.figure(figsize=(18, num_samples * 4))

    vmax = 0.3

    for i in range(num_samples):
        L, ab = dataset[start_idx + i]

        if L.dim() == 3:          # [1,H,W]
            L = L.unsqueeze(0)    # [B,1,H,W]

        L = L.to(device)

        with torch.no_grad():
            pred_ab = model(L)

        
        L_img = L[0, 0].cpu().numpy()                     # BnW
        ab_gt = ab.permute(1, 2, 0).cpu().numpy()         # GT ab
        ab_pd = pred_ab[0].permute(1, 2, 0).cpu().numpy() # Pred ab

        gt_rgb   = lab_to_rgb(L_img, ab_gt)
        pred_rgb = lab_to_rgb(L_img, ab_pd)

        error_map = np.mean(np.abs(gt_rgb - pred_rgb), axis=2)

        row = i * 4

        #bnw input
        plt.subplot(num_samples, 4, row + 1)
        plt.imshow(L_img, cmap="gray")
        plt.title("Input (BnW)")
        plt.axis("off")

        # ground truth
        plt.subplot(num_samples, 4, row + 2)
        plt.imshow(gt_rgb)
        plt.title("Ground Truth")
        plt.axis("off")

        # prediksi
        plt.subplot(num_samples, 4, row + 3)
        plt.imshow(pred_rgb)
        plt.title("Predicted")
        plt.axis("off")

        # error map
        ax = plt.subplot(num_samples, 4, row + 4)
        im = ax.imshow(error_map, cmap="hot", vmin=0, vmax=vmax)
        ax.set_title(f"Error Map\nMean: {error_map.mean():.4f}")
        ax.axis("off")

        cbar = plt.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
        cbar.set_label("Pixel Error")

    plt.tight_layout()
    plt.show()

# %%
def train_model(model, save_path):
    best_val_loss = float("inf")
    counter = 0
    best_epoch = 0

    train_losses = []
    val_losses = []

    print("Start training...")
    for epoch in range(EPOCHS):
        # ===== TRAIN =====
        model.train()
        running_train_loss = 0.0

        for input_l, target_ab in train_loader:
            input_l = input_l.to(device)
            target_ab = target_ab.to(device)

            output_ab = model(input_l)
            loss = criterion(output_ab, target_ab)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_train_loss += loss.item()

        avg_train_loss = running_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # ===== VALIDATION =====
        model.eval()
        running_val_loss = 0.0

        with torch.no_grad():
            for input_l, target_ab in val_loader:
                input_l = input_l.to(device)
                target_ab = target_ab.to(device)

                output_ab = model(input_l)
                loss = criterion(output_ab, target_ab)
                running_val_loss += loss.item()

        avg_val_loss = running_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)

        #earlystop
        if avg_val_loss < best_val_loss - MIN_DELTA:
            best_val_loss = avg_val_loss
            best_epoch = epoch + 1
            counter = 0

            torch.save({
                "epoch": best_epoch,
                "model_state_dict": model.state_dict(),
                "optimizer_state_dict": optimizer.state_dict(),
                "val_loss": best_val_loss
            }, save_path)
        else:
            counter += 1

        print(
            f"Epoch [{epoch+1}/{EPOCHS}] | "
            f"Train Loss: {avg_train_loss:.4f} | "
            f"Val Loss: {avg_val_loss:.4f} | "
            f"ES Counter: {counter}/{PATIENCE}"
        )

        if counter >= PATIENCE:
            print("Early stopping triggered.")
            break

    print("Training finished.")
    print(f"Best model at epoch {best_epoch} with val loss {best_val_loss:.4f}")

    return train_losses, val_losses, best_epoch, best_val_loss

# %%
from skimage.metrics import peak_signal_noise_ratio as psnr
from skimage.metrics import structural_similarity as ssim

def compute_metrics(model, dataset):
    model.eval()
    psnr_list, ssim_list = [], []

    for i in range(len(dataset)):
        with torch.no_grad():
            L, ab = dataset[i]

            # pastikan L ada batch dim
            if L.dim() == 3:        # [1,H,W]
                L = L.unsqueeze(0)  # [B,1,H,W]

            L = L.to(device)
            pred_ab = model(L)      # [B,2,H,W]

        # =======================
        # Handle L
        # =======================
        L_img = L[0,0].cpu().numpy()   # [H,W]

        # =======================
        # Handle GT ab
        # =======================
        if ab.dim() == 4:              # [B,2,H,W]
            ab_gt = ab[0].permute(1,2,0).cpu().numpy()
        elif ab.dim() == 3:            # [2,H,W]
            ab_gt = ab.permute(1,2,0).cpu().numpy()
        else:                          # [H,W,2]
            ab_gt = ab.cpu().numpy()

        # =======================
        # Predicted ab
        # =======================
        ab_pred = pred_ab[0].permute(1,2,0).cpu().numpy()

        # =======================
        # LAB → RGB
        # =======================
        gt_rgb   = lab_to_rgb(L_img, ab_gt)
        pred_rgb = lab_to_rgb(L_img, ab_pred)

        # =======================
        # Metrics
        # =======================
        psnr_val = psnr(gt_rgb, pred_rgb, data_range=1.0)
        ssim_val = ssim(gt_rgb, pred_rgb, channel_axis=2, data_range=1.0)

        psnr_list.append(psnr_val)
        ssim_list.append(ssim_val)

    return psnr_list, ssim_list

# %%
def plot_psnr_ssim_distribution(psnr_list, ssim_list, model_name="Model"):
    psnr = np.array(psnr_list)
    ssim = np.array(ssim_list)

    plt.figure(figsize=(12,5))

    # ===== PSNR Scatter =====
    plt.subplot(1,2,1)
    plt.scatter(range(len(psnr)), psnr)
    plt.axhline(psnr.mean(), linestyle='--', label=f"Mean PSNR = {psnr.mean():.2f}")
    plt.xlabel("Image Index")
    plt.ylabel("PSNR")
    plt.title(f"{model_name} PSNR Distribution")
    plt.legend()

    # ===== SSIM Scatter =====
    plt.subplot(1,2,2)
    plt.scatter(range(len(ssim)), ssim)
    plt.axhline(ssim.mean(), linestyle='--', label=f"Mean SSIM = {ssim.mean():.3f}")
    plt.xlabel("Image Index")
    plt.ylabel("SSIM")
    plt.title(f"{model_name} SSIM Distribution")
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **VGG16 UNET**

# %%
class vgg_unet(nn.Module):
    def __init__(self):
        super().__init__()

        vgg = models.vgg16(pretrained=True)
        vgg.features[0] = nn.Conv2d(1, 64, 3, padding=1)

        feats = list(vgg.features.children())

        # ENCODER
        self.encoder1 = nn.Sequential(*feats[0:5])    # 64
        self.encoder2 = nn.Sequential(*feats[5:10])   # 128
        self.encoder3 = nn.Sequential(*feats[10:17])  # 256
        self.encoder4 = nn.Sequential(*feats[17:24])  # 512
        self.encoder5 = nn.Sequential(*feats[24:31])  # 512

        # CHANNEL ADAPTER (channel alignment for fair comparison)
        self.adapt_e2 = nn.Conv2d(128, 64, 1)
        self.adapt_e3 = nn.Conv2d(256, 128, 1)
        self.adapt_e4 = nn.Conv2d(512, 256, 1)

        # DECODER
        self.decoder4 = self._block(512, 256)
        self.decoder3 = self._block(256 + 256, 128)
        self.decoder2 = self._block(128 + 128, 64)
        self.decoder1 = self._block(64 + 64, 32)

        self.final = nn.Conv2d(32, 2, kernel_size=3, padding=1)
        self.upsample = nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)

    def _block(self, in_c, out_c):
        return nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Upsample(scale_factor=2, mode="bilinear", align_corners=True)
        )

    def forward(self, x):
        e1 = self.encoder1(x)      # 64
        e2 = self.encoder2(e1)     # 128
        e3 = self.encoder3(e2)     # 256
        e4 = self.encoder4(e3)     # 512
        e5 = self.encoder5(e4)     # 512

        e2 = self.adapt_e2(e2)     # 128 → 64
        e3 = self.adapt_e3(e3)     # 256 → 128
        e4 = self.adapt_e4(e4)     # 512 → 256

        d4 = self.decoder4(e5)
        d3 = self.decoder3(torch.cat([d4, e4], dim=1))
        d2 = self.decoder2(torch.cat([d3, e3], dim=1))
        d1 = self.decoder1(torch.cat([d2, e2], dim=1))

        out = self.final(d1)
        out = self.upsample(out)
        return out

# %%
model_vgg_unet = vgg_unet().to(device)
criterion = nn.L1Loss()
optimizer = optim.Adam(model_vgg_unet.parameters(), lr=LR)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 221MB/s]

# %%
train_losses, val_losses, best_epoch, best_val_loss = train_model(model_vgg_unet, "vgg_unet.pth")
# Out:
# Start training...
# Epoch [1/50] | Train Loss: 0.1513 | Val Loss: 0.1012 | ES Counter: 0/15
# Epoch [2/50] | Train Loss: 0.0896 | Val Loss: 0.0857 | ES Counter: 0/15
# Epoch [3/50] | Train Loss: 0.0859 | Val Loss: 0.0847 | ES Counter: 0/15
# Epoch [4/50] | Train Loss: 0.0876 | Val Loss: 0.0837 | ES Counter: 0/15
# Epoch [5/50] | Train Loss: 0.0842 | Val Loss: 0.0847 | ES Counter: 1/15
# Epoch [6/50] | Train Loss: 0.0834 | Val Loss: 0.0821 | ES Counter: 0/15
# Epoch [7/50] | Train Loss: 0.0822 | Val Loss: 0.0817 | ES Counter: 0/15
# Epoch [8/50] | Train Loss: 0.0813 | Val Loss: 0.0802 | ES Counter: 0/15
# Epoch [9/50] | Train Loss: 0.0809 | Val Loss: 0.0804 | ES Counter: 1/15
# Epoch [10/50] | Train Loss: 0.0818 | Val Loss: 0.0819 | ES Counter: 2/15
# Epoch [11/50] | Train Loss: 0.0807 | Val Loss: 0.0796 | ES Counter: 0/15
# Epoch [12/50] | Train Loss: 0.0797 | Val Loss: 0.0796 | ES Counter: 1/15
# Epoch [13/50] | Train Loss: 0.0797 | Val Loss: 0.0793 | ES Counter: 0/15
# Epoch [14/50] | Train Loss: 0.0794 | Val Loss: 0.0791 | ES Counter: 0/15
# Epoch [15/50] | Train Loss: 0.0785 | Val Loss: 0.0796 | ES Counter: 1/15
# Epoch [16/50] | Train Loss: 0.0776 | Val Loss: 0.0789 | ES Counter: 0/15
# Epoch [17/50] | Train Loss: 0.0773 | Val Loss: 0.0782 | ES Counter: 0/15
# Epoch [18/50] | Train Loss: 0.0779 | Val Loss: 0.0792 | ES Counter: 1/15
# Epoch [19/50] | Train Loss: 0.0762 | Val Loss: 0.0786 | ES Counter: 2/15
# Epoch [20/50] | Train Loss: 0.0756 | Val Loss: 0.0784 | ES Counter: 3/15
# Epoch [21/50] | Train Loss: 0.0749 | Val Loss: 0.0793 | ES Counter: 4/15
# Epoch [22/50] | Train Loss: 0.0740 | Val Loss: 0.0783 | ES Counter: 5/15
# Epoch [23/50] | Train Loss: 0.0734 | Val Loss: 0.0796 | ES Counter: 6/15
# Epoch [24/50] | Train Loss: 0.0736 | Val Loss: 0.0788 | ES Counter: 7/15
# Epoch [25/50] | Train Loss: 0.0719 | Val Loss: 0.0791 | ES Counter: 8/15
# Epoch [26/50] | Train Loss: 0.0705 | Val Loss: 0.0791 | ES Counter: 9/15
# Epoch [27/50] | Train Loss: 0.0694 | Val Loss: 0.0802 | ES Counter: 10/15
# Epoch [28/50] | Train Loss: 0.0691 | Val Loss: 0.0802 | ES Counter: 11/15
# Epoch [29/50] | Train Loss: 0.0679 | Val Loss: 0.0786 | ES Counter: 12/15
# Epoch [30/50] | Train Loss: 0.0670 | Val Loss: 0.0807 | ES Counter: 13/15
# Epoch [31/50] | Train Loss: 0.0733 | Val Loss: 0.0803 | ES Counter: 14/15
# Epoch [32/50] | Train Loss: 0.0666 | Val Loss: 0.0804 | ES Counter: 15/15
# Early stopping triggered.
# Training finished.
# Best model at epoch 17 with val loss 0.0782

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("L1 Loss")
plt.title("Training vs Validation Loss - VGG16 UNet")
plt.legend()
plt.grid(True)
plt.show()

# %%
plot_results(model_vgg_unet, test_dataset, 23)
# Out:
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3120 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3036 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20165 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 5589 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34102 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34621 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40111 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 26753 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38349 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30987 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)

# %%
psnr_list, ssim_list = compute_metrics(model_vgg_unet, test_dataset)
plot_psnr_ssim_distribution(psnr_list, ssim_list, "vgg16-UNet")
# Out:
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 55535 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 51032 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 33398 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35678 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 4299 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 4278 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31798 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 33868 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 23773 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24725 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 45159 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28763 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13329 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 11721 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32014 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32113 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29356 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24980 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 39112 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37576 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28107 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30374 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32815 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25390 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29180 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31507 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 58845 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 46466 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 43577 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 45620 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27467 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27271 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 14948 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 15830 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 44728 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 46329 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34031 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 33188 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 44289 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31721 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24999 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24762 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38492 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38637 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41706 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40157 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3120 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3036 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20165 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 6650 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34102 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34232 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40111 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22934 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38349 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29424 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22093 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21655 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13931 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 12212 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28492 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29586 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37781 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38453 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27053 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27430 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24370 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 12832 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 19876 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 19849 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 33575 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 33374 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13232 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20766 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 16475 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 18190 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 53757 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 53561 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 55875 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 44416 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35998 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35341 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 45665 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 44344 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28497 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28362 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 52037 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 45057 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21270 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21188 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31261 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31152 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32576 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 33637 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 39471 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35060 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31912 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29200 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41818 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 42499 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 42665 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 45289 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 18833 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 19117 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34127 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 7292 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32598 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31457 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 48454 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 48607 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 10301 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 10251 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 6486 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 6749 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 49486 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 49550 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32655 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32164 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34253 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37847 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 18674 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 16836 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 42050 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40489 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 50424 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 51064 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 16079 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 16517 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 43873 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38387 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13960 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 12499 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3973 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3875 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 53417 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 59207 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37016 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37930 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20419 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24755 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 18923 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 19685 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25038 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24153 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13404 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 18670 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37928 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37936 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27749 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30398 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 48029 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 46165 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29352 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27012 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 12089 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 4146 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3496 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34890 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 36769 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 65266 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 64738 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 23170 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22499 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 17644 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 26048 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22567 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21292 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 54575 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 49526 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37087 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35227 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 16929 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 12672 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31402 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32130 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25736 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25336 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35881 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35959 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32262 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32507 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40967 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40146 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20770 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 17768 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27874 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30184 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38822 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35170 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 6534 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 7834 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40311 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41286 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 59357 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 57027 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 49670 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 50061 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22360 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25580 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 49521 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 50332 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 50416 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 51681 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24690 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 23626 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 42634 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 39517 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40016 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41255 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28523 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28979 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 52433 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 53083 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32866 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32999 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 26184 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22734 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28594 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13245 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24543 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24506 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 49298 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 47838 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 42112 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41201 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21554 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21320 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 43651 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 44972 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 42822 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 46395 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27832 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25114 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 2070 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 1880 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41304 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41631 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29707 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31099 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28216 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31449 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 23118 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22160 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 46493 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 47085 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 23440 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27919 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 15320 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13676 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30613 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30487 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40658 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# ...
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30517 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 6559 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 6118 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25504 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25442 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29969 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30361 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 56814 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 54726 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38158 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38916 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25175 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 26728 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 14071 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 23876 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38096 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38947 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20014 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20279 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 26382 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29612 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24787 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 26304 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37343 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 43941 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 35824 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 33631 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38831 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38795 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 14399 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 15460 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3870 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3954 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 19044 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21680 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 45116 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 45541 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 14448 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 16048 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 9615 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 9644 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 2472 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 3446 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 6519 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 5672 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34647 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 34108 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24818 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 20161 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22912 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22958 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27198 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28092 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 7987 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13059 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 18640 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 15821 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 12240 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 9324 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 38746 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 40019 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 32429 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27964 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 27275 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 31100 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13313 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 13778 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 37396 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 2164 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 1608 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 30684 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28808 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 50570 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 47704 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21123 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 22587 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 25380 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 23646 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 24802 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 21432 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 28988 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 41186 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29523 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
# /tmp/ipykernel_47/1358663669.py:13: UserWarning: Conversion from CIE-LAB, via XYZ to sRGB color space resulted in 29746 negative Z values that have been clipped to zero
#   rgb = lab2rgb(lab)
